# %% [markdown]
# # POS&NER analyzing
#
# **โจทย์**
#
# * การหากิจกรรมและสิ่งที่เกี่ยวข้องกับข่าวแต่ละประเภท
# *   องค์กรหรือหน่วยงานที่เกี่ยวข้องกับข่าวของแต่ประเภท

# %% [markdown]
#  # Dataset
#
#
# Scrape จาก www.snook.com ระหว่างวันที่ 1 ก.พ. 2023 ถึง 23 ก.พ. 2023 ซึ่งประกอบด้วย
#
#
# *  ข่าวกีฬา (Sport)
# *  ข่าวไอที (Hitech)
# *  ข่าวเศรษฐกิจ(Money)
# *  ข่าวหนัง(Movie)
# *  ข่าวการศึกษา( Campus)
# *  ข่าวเกมส์ (Game)
# *  ข่าวท่องเที่ยว(Travel)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pythainlp
# !pip install pythainlp["full"]
# !pip install attacut
# !pip install transformers
# !pip install sentencepiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pythainlp
#   Downloading pythainlp-3.1.1-py3-none-any.whl (9.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 41.9 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.9/dist-packages (from pythainlp) (2.25.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.22.0->pythainlp) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests>=2.22.0->pythainlp) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.22.0->pythainlp) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.22.0->pythainlp) (1.26.14)
# Installing collected packages: pythainlp
# Successfully installed pythainlp-3.1.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting attacut
#   Downloading attacut-1.0.6-py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 16.9 MB/s eta 0:00:00
# Collecting ssg>=0.0.4
#   Downloading ssg-0.0.8-py3-none-any.whl (473 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 473.8/473.8 KB 48.7 MB/s eta 0:00:00
# Collecting docopt>=0.6.2
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.2.0 in /usr/local/lib/python3.9/dist-packages (from attacut) (1.13.1+cu116)
# Requirement already satisfied: pyyaml>=5.1.2 in /usr/local/lib/python3.9/dist-packages (from attacut) (6.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.9/dist-packages (from attacut) (1.22.4)
# Collecting fire>=0.1.3
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 KB 10.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.9/dist-packages (from attacut) (1.15.0)
# Collecting nptyping>=0.2.0
#   Downloading nptyping-2.5.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.9/dist-packages (from fire>=0.1.3->attacut) (2.2.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from nptyping>=0.2.0->attacut) (4.5.0)
# Collecting python-crfsuite>=0.9.6
#   Downloading python_crfsuite-0.9.9-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 66.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.32.2 in /usr/local/lib/python3.9/dist-packages (from ssg>=0.0.4->attacut) (4.65.0)
# Building wheels for collected packages: docopt, fire
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=85679f8082e9fcf61a1c13c55a24ad6d2975b66df9bd780cca31c53e6e9d8971
#   Stored in directory: /root/.cache/pip/wheels/70/4a/46/1309fc853b8d395e60bafaf1b6df7845bdd82c95fd59dd8d2b
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116949 sha256=cec14075c852c2847df21a3ca6adc2bf4346aa19d542efb6696c5710ffe97eca
#   Stored in directory: /root/.cache/pip/wheels/f7/f1/89/b9ea2bf8f80ec027a88fef1d354b3816b4d3d29530988972f6
# Successfully built docopt fire
# Installing collected packages: python-crfsuite, docopt, nptyping, fire, ssg, attacut
# Successfully installed attacut-1.0.6 docopt-0.6.2 fire-0.5.0 nptyping-2.5.0 python-crfsuite-0.9.9 ssg-0.0.8
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.26.1-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 51.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.9.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 81.5 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.25.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.1-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 22.4 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.14)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.13.1 tokenizers-0.13.2 transformers-4.26.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 17.9 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.97

# %%
import pandas as pd
import string
import re

# %%
df_sel=pd.read_pickle('/content/drive/MyDrive/NLP/Day2/POS_NER_analysis/Snook_scraping.pkl')

# %%
df_sel.columns
# Out:
# Index(['URL', 'Text', 'Time', 'new_section', 'Text_real'], dtype='object')

# %%
df_sel.head(1)
# Out:
#                                       URL  \
# 0  https://www.sanook.com/campus/1413467/
#
#                                                 Text                   Time  \
# 0  ['สนับสนุนเนื้อหา', 'ไม่ว่าจะปีเก่าหรือปีใหม่ ...  05 ก.พ. 66 (18:00 น.)
#
#   new_section                                          Text_real
# 0      Campus  [ไม่ว่าจะปีเก่าหรือปีใหม่ สิ่งที่ผู้คนให้ความส...

# %% [markdown]
# **Parameter**
#
#
# *   URL(str) : linkของข่าว
# *   Text(list): ข้อความข่าวที่ Scrape มาจาก tag p
# *  Time(str) : วันและเวลาของข่าว
# *  new_section(str) : ประเภทของข่าว
# * Text_real(list) : ข้อความที่ Scrape มาจาก tag p และเลือกมาเฉพาะเนื้อหาของข่าว

# %% [markdown]
# # Explore

# %%
df_sel['new_section'].value_counts()
# Out:
# Sport     307
# Hitech    176
# Money     142
# Movie     110
# Campus    109
# Game       98
# Travel     85
# Name: new_section, dtype: int64

# %%
df_sel['new_section'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df_sel['Text_real'][0]
# Out:
# ['ไม่ว่าจะปีเก่าหรือปีใหม่ สิ่งที่ผู้คนให้ความสนใจก็คงจะหนีไม่พ้นเรื่องของปากท้องเป็นสำคัญ คนทำงานยังต้องตั้งหน้าตั้งตาพัฒนาตัวเองเพื่อให้ได้ไปต่อในสายงานที่ทำอยู่ เพราะนอกจากเทคโนโลยีจะเข้ามาเป็นตัวแปรสำคัญแล้ว คนด้วยกันเองก็ยังคงเป็นคู่แข่ง เพราะถ้าหากองค์กรจำเป็นต้องลดขนาดเพื่อให้สอดคล้องกับสภาวะเศรษฐกิจ คนทำงานส่วนหนึ่งต้องออกจากสายงานไป และมีบางส่วนที่ได้อยู่ต่อ คำถามคือ คนทำงานแบบไหนล่ะที่องค์กรจะยังเก็บไว้ หรือคนทำงานแบบไหนที่องค์กรต้องการ คนที่มีศักยภาพมากพอที่จะจ้างงาน',
#  'เรื่องปกติที่องค์กรต่าง ๆ จะเฟ้นหาบุคลากรที่มีคุณภาพเข้ามาเป็นส่วนหนึ่งในการพัฒนาทีม และเพื่อการเติบโตขององค์กร ในจำนวนของผู้สมัครงานนับร้อยนับพัน องค์กรจะต้องคัดเอาบุคลากรที่มีศักยภาพที่เป็นประโยชน์ต่อทีมมากที่สุดเข้ามา ซึ่งองค์กรมักจะมองหาผู้ที่มีทักษะการทำงานทั้งในด้าน soft skills และ hard skills หรือแม้แต่ meta skills ซึ่งเป็นทักษะการเรียนรู้ตลอดชีวิต เป็นความสามารถในการพร้อมรับความเปลี่ยนแปลงที่จะเกิดขึ้น เพื่อนำมาพัฒนาการทำงาน เพราะเราต้องรับมือกับความเปลี่ยนแปลงที่ถาโถมเข้ามาอย่างรวดเร็ว จึงต้องมีทักษะในการเอาตัวรอดจากสถานการณ์ที่คนอื่น ๆ ก็พยายามดิ้นรนเหมือนเช่นกัน แต่ใครไวกว่าได้เปรียบ',
#  '“ทัศนคติ” มักจะถูกนำมาพิจารณาเป็นก้าวแรกสู่ความสำเร็จทางหน้าที่การงาน มันเป็นปัจเจกเฉพาะตัวว่าใครมีแนวความคิดเห็นต่อมุมมองในการทำงานอย่างไรที่จะพาตัวเองและองค์กรไปสู่ความสำเร็จ หากมีทัศนคติที่ใช่และทัศนคติเชิงบวก ก็มีแนวโน้มว่าจะได้ไปต่อ นอกจากนี้ เรื่องของกรอบความคิดที่เป็นตัวกำหนดทัศนคติก็เช่นกัน การรับบุคลากรใหม่เข้ามาทำงานในองค์กรในยุคที่ทุกอย่างเร็วต่อการเปลี่ยนแปลง ความไม่แน่นอนเกิดขึ้นได้ตลอดเวลา ทำให้หลายองค์กรมองหาคนประเภทที่กล้าเผชิญหน้ากับการเปลี่ยนแปลง ต่อให้ต้องเจอความล้มเหลวก็ยังลุกขึ้นมาใหม่ได้เสมอ รวมถึงไม่กล้วความท้าทายต่าง ๆ นี่เป็นคุณสมบัติของ growth mindset ที่องค์กรมองหา',
#  'growth mindset เป็นลักษณะความคิดและความเชื่อว่าฉันนี่แหละที่เป็นคนกำหนดว่าต้องรู้อะไร ดังนั้น ผู้ที่มี mindset แบบนี้จะเปิดรับการเรียนรู้ทุกอย่างเพื่อนำมาใช้พัฒนา ปรับปรุง และเติมเต็มในส่วนที่ตนเองยังไม่มี เชื่อว่าความเก่ง ความฉลาดเป็นสิ่งที่สร้างขึ้นได้ จึงกลายเป็นคุณสมบัติที่ผู้จ้างงานมองหาในตัวพนักงาน เนื่องจากเป็นแนวความคิดที่พร้อมจะเปลี่ยนแปลงตนเองเสมอเพื่อให้เข้ากับสถานการณ์ของความไม่แน่นอน การปรับตัวได้เร็วและรับมือกับความเปลี่ยนแปลงได้ไวจะช่วยให้ก้าวข้ามสถานการณ์ไม่สู้ดีได้ ซึ่งจะมีผลต่อทุกสิ่งในการทำงาน ตั้งแต่วิธีตอบสนองต่อคำติชม ไปจนถึงความมุ่งมั่นตั้งใจที่จะสร้างสรรค์สิ่งใหม่ ๆ และเป็นส่วนหนึ่งในการพัฒนาทีม',
#  'เนื่องจาก growth mindset เป็นกรอบแนวคิดของคนที่แสวงหาการเติบโต การเติมเต็มในส่วนที่ตัวเองขาด ไม่หยุดที่จะเรียนรู้และพัฒนาตนเอง คนประเภทนี้เชื่อว่าตราบใดที่โลกไม่หยุดหมุน เราก็หยุดพัฒนาตัวเองไม่ได้ ทำให้องค์กรเห็นว่าคนประเภทนี้คือคนที่จะสามารถปรับตัวได้หากความเปลี่ยนแปลงมาเยือน รู้จักพลิกวิกฤติให้เป็นโอกาส อีกทั้งยังแสดงให้เห็นถึงความพยายามที่จะขวนขวายเอาตัวรอด เพื่อให้ตัวเองเก่งขึ้นเรื่อย ๆ อย่างไม่มีที่สิ้นสุด growth mindset นี่เองที่เป็นกุญแจนำไปสู่ความสำเร็จไม่ว่าจะกับเรื่องใดก็ตาม เพราะมันคือชุดความคิดว่าตัวเองมีความสามารถ รู้ว่าตัวเองต้องพัฒนาอะไร ต้องทำอะไรเพื่อพาตัวเองไปข้างหน้า เปลี่ยนแปลงตัวเองเพื่อการเติบโตgrowth mindset ต้องกล้าเปลี่ยนแปลงตัวเองเพื่อรับมือกับสถานการณ์ต่าง ๆ',
#  'คนทำงานประเภทที่มีความคิดแบบ growth mindset จะมองว่าอุปสรรคที่เกิดขึ้นนั้นไม่ใช่ปัญหาที่ต้องมานั่งฟูมฟาย ไม่มีประโยชน์ แต่คนเหล่านี้จะพลิกแพลงวิกฤติให้กลายเป็นโอกาส พร้อมเปลี่ยนแปลงและพัฒนาตัวเอง ค่อย ๆ เรียนรู้ ไม่ดูแคลนความพยายามและความสามารถของตนเอง เชื่อว่าตัวเองจะสามารถก้าวข้ามผ่านวิกฤติและความกลัวได้ในที่สุด ดังนั้น อุปสรรคจึงกลายเป็นโอกาสที่ทำให้คนเหล่านี้ได้พัฒนาตนเองและก้าวข้ามขีดจำกัด ทำงานหนักในช่วงเปลี่ยนผ่าน ขวนขวายเรียนรู้ หรือลองสิ่งใหม่ โดยไม่สนว่าจะสำเร็จหรือไม่ เพราะถ้าไม่ลองก็ไม่รู้ พลาดก็ไม่เห็นจะเสียหาย ดีเสียอีกที่ได้ประสบการณ์']

# %% [markdown]
# # Preprocessing text

# %% [markdown]
# **การทำความสะอาดข้อความหรือ preprocessing**
#
# *   แปลงตัวอักษรภาษาอังกฤษจากตัวพิมพ์ใหญ่เป็นตัวพิมพ์เล็ก
# *   ลบ \n,xa0 และ u200b ออกจากข้อความ
# *   ลบ punctuation ออกจากข้อความ

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
'[{}]'.format(re.escape(string.punctuation))

# %%
def preprocess_cleansing(text):
      ''' Converting  text to lower case
      and  removing all punctuation'''
      # แปลงตัวอักษรตัวใหญ่ให้เป็นตัวเล็กทั้งหมด
      text=text.lower()
      # ลบ punctuation ทั้งหมด
      text = re.sub('\n', '', text)
      text = re.sub(r'[{}]'.format(string.punctuation), '', text)
      text = re.sub('xa0|u200b', '', text)
      return text

# %%
def cleansing_list_of_text(list_of_text):
    ''' preprocessing text in list'''
    result=[]
    for text in list_of_text:
        # preprocess_cleansing
        clean_text=preprocess_cleansing(text)
        result.append(clean_text)
    # เลือกเฉพาะ text ที่มีจำนวนพยางค์มากกว่า 0
    result=[w for w in result if len(w)>1]
    return result

# %%
# ทำความสะอาดข้อความใน list
df_sel['Text_real']=df_sel['Text_real'].apply(lambda x:cleansing_list_of_text(x))

# %%
df_sel['Text_real'][1]
# Out:
# ['มนุษย์ติดโซเชียล พร้อมพาส่องหนุ่มหล่อสาวสวยมากความสามารถ ชอบอัปเดตเทรนด์ของโลก มีอะไรปังๆ ดังๆ ก็ไม่พลาดเอามาเล่าให้เพื่อนๆ ได้อ่านกัน',
#  'วาเลนไทน์ นอกจากจะเป็นเทศกาลแห่งความรักแล้ว ยังแอบเป็นเทศกาลให้การเปย์ การให้ของขวัญสำหรับคู่รักหนุ่มสาวที่กำลังมีความหวานชื่นรื่นรมย์อีกด้วยนะ ไม่ว่าสาวๆ หรือหนุ่มๆ ก็เรียกได้ว่าตั้งหน้าตั้งตาคอยของขวัญดีๆ จากคนรักของตัวเอง ที่ได้แล้วทำให้หัวใจพองโตกันตลอดวันเลยจริงๆ',
#  'วันนี้ sanook campus เราก็ได้รวบรวม ของขวัญวาเลนไทน์ เก๋ๆ ที่เหมาะกับการมอบให้คนรักในเทศกาลแห่งความรักนี้กันซักหน่อย จะมีอะไรบ้าง มาดูกันเลย']

# %%
# เชื่อม list ของข้อความด้วยคำสั่ง join()
df_sel['Text_combine']=df_sel['Text_real'].apply(lambda x:' '.join(x))

# %%
df_sel['Text_combine'][1]
# Out:
# 'มนุษย์ติดโซเชียล พร้อมพาส่องหนุ่มหล่อสาวสวยมากความสามารถ ชอบอัปเดตเทรนด์ของโลก มีอะไรปังๆ ดังๆ ก็ไม่พลาดเอามาเล่าให้เพื่อนๆ ได้อ่านกัน วาเลนไทน์ นอกจากจะเป็นเทศกาลแห่งความรักแล้ว ยังแอบเป็นเทศกาลให้การเปย์ การให้ของขวัญสำหรับคู่รักหนุ่มสาวที่กำลังมีความหวานชื่นรื่นรมย์อีกด้วยนะ ไม่ว่าสาวๆ หรือหนุ่มๆ ก็เรียกได้ว่าตั้งหน้าตั้งตาคอยของขวัญดีๆ จากคนรักของตัวเอง ที่ได้แล้วทำให้หัวใจพองโตกันตลอดวันเลยจริงๆ วันนี้ sanook campus เราก็ได้รวบรวม ของขวัญวาเลนไทน์ เก๋ๆ ที่เหมาะกับการมอบให้คนรักในเทศกาลแห่งความรักนี้กันซักหน่อย จะมีอะไรบ้าง มาดูกันเลย'

# %% [markdown]
# # Tokenization

# %%
from pythainlp import word_tokenize

# %%
# ตัดคำโดยใช้คำสั่ง word_tokenize() ซึ่งใช้อัลกอริทึมของ attacut
df_sel['token']=df_sel['Text_combine'].apply(lambda x:word_tokenize(x, engine="attacut"))

# %%
df_sel['token'][1][:10]
# Out:
# ['มนุษย์',
#  'ติด',
#  'โซเชียล',
#  ' ',
#  'พร้อม',
#  'พา',
#  'ส่อง',
#  'หนุ่ม',
#  'หล่อ',
#  'สาว']

# %% [markdown]
# # Part Of Speech(POS)

# %%
from pythainlp.tag import pos_tag

# %%
# หาค่า pos ของคำในประโยค
df_sel['pos_tag']=df_sel['token'].apply(lambda x:pos_tag(x, corpus='orchid'))

# %%
df_sel['pos_tag'][1]
# Out:
# [('มนุษย์', 'NCMN'),
#  ('ติด', 'VSTA'),
#  ('โซเชียล', 'NCMN'),
#  (' ', 'PUNC'),
#  ('พร้อม', 'VSTA'),
#  ('พา', 'NCMN'),
#  ('ส่อง', 'NCMN'),
#  ('หนุ่ม', 'NCMN'),
#  ('หล่อ', 'NCMN'),
#  ('สาว', 'NCMN'),
#  ('สวย', 'VATT'),
#  ('มาก', 'ADVN'),
#  ('ความ', 'FIXN'),
#  ('สามารถ', 'XVAM'),
#  (' ', 'PUNC'),
#  ('ชอบ', 'VACT'),
#  ('อัปเดตเทรนด์', 'NCMN'),
#  ('ของ', 'RPRE'),
#  ('โลก', 'NCMN'),
#  (' ', 'PUNC'),
#  ('มี', 'VSTA'),
#  ('อะไร', 'PNTR'),
#  ('ปัง', 'VACT'),
#  ('ๆ', 'PUNC'),
#  (' ', 'PUNC'),
#  ('ดัง', 'RPRE'),
#  ('ๆ', 'NCMN'),
#  (' ', 'PUNC'),
#  ('ก็', 'JSBR'),
#  ('ไม่', 'NEG'),
#  ('พลาด', 'VACT'),
#  ('เอา', 'VACT'),
#  ('มา', 'XVAE'),
#  ('เล่า', 'VACT'),
#  ('ให้', 'JSBR'),
#  ('เพื่อน', 'ADVN'),
#  ('ๆ', 'NCMN'),
#  (' ', 'PUNC'),
#  ('ได้', 'XVAM'),
#  ('อ่าน', 'VACT'),
#  ('กัน', 'ADVN'),
#  (' ', 'PUNC'),
#  ('วาเลนไทน์', 'NCMN'),
#  (' ', 'PUNC'),
#  ('นอก', 'VATT'),
#  ('จาก', 'RPRE'),
#  ('จะ', 'XVBM'),
#  ('เป็น', 'VSTA'),
#  ('เทศกาล', 'NCMN'),
#  ('แห่ง', 'CNIT'),
#  ('ความ', 'FIXN'),
#  ('รัก', 'VSTA'),
#  ('แล้ว', 'XVAE'),
#  (' ', 'PUNC'),
#  ('ยัง', 'XVBM'),
#  ('แอบ', 'NCMN'),
#  ('เป็น', 'VSTA'),
#  ('เทศกาล', 'NCMN'),
#  ('ให้', 'JSBR'),
#  ('การ', 'FIXN'),
#  ('เปย์', 'VACT'),
#  (' ', 'PUNC'),
#  ('การ', 'FIXN'),
#  ('ให้', 'VACT'),
#  ('ของขวัญ', 'NCMN'),
#  ('สำหรับ', 'RPRE'),
#  ('คู่', 'NCMN'),
#  ('รัก', 'NCMN'),
#  ('หนุ่มสาว', 'NCMN'),
#  ('ที่', 'PREL'),
#  ('กำลัง', 'XVBM'),
#  ('มี', 'VSTA'),
#  ('ความ', 'FIXN'),
#  ('หวาน', 'VSTA'),
#  ('ชื่นรื่นรมย์', 'NCMN'),
#  ('อีก', 'DDBQ'),
#  ('ด้วย', 'RPRE'),
#  ('นะ', 'NCMN'),
#  (' ', 'PUNC'),
#  ('ไม่ว่า', 'JCRG'),
#  ('สาว', 'NCMN'),
#  ('ๆ', 'PUNC'),
#  (' ', 'PUNC'),
#  ('หรือ', 'JCRG'),
#  ('หนุ่ม', 'NCMN'),
#  ('ๆ', 'NCMN'),
#  (' ', 'PUNC'),
#  ('ก็', 'JSBR'),
#  ('เรียก', 'VACT'),
#  ('ได้', 'XVAE'),
#  ('ว่า', 'JSBR'),
#  ('ตั้ง', 'VACT'),
#  ('หน้าตั้งตา', 'NCMN'),
#  ('คอย', 'VACT'),
#  ('ของขวัญ', 'NCMN'),
#  ('ดี', 'VATT'),
#  ('ๆ', 'PUNC'),
#  (' ', 'PUNC'),
#  ('จาก', 'RPRE'),
#  ('คน', 'NCMN'),
#  ('รัก', 'NCMN'),
#  ('ของ', 'RPRE'),
#  ('ตัว', 'NCMN'),
#  ('เอง', 'PDMN'),
#  (' ', 'PUNC'),
#  ('ที่', 'PREL'),
#  ('ได้', 'VSTA'),
#  ('แล้ว', 'XVAE'),
#  ('ทำ', 'VACT'),
#  ('ให้', 'JSBR'),
#  ('หัวใจ', 'NCMN'),
#  ('พอง', 'NCMN'),
#  ('โต', 'VATT'),
#  ('กัน', 'ADVN'),
#  ('ตลอด', 'RPRE'),
#  ('วัน', 'NCMN'),
#  ('เลย', 'XVAE'),
#  ('จริง', 'ADVN'),
#  ('ๆ', 'PUNC'),
#  (' ', 'PUNC'),
#  ('วัน', 'NCMN'),
#  ('นี้', 'DDAC'),
#  (' ', 'PUNC'),
#  ('sanook', 'NCMN'),
#  (' ', 'PUNC'),
#  ('campus', 'NCMN'),
#  (' ', 'PUNC'),
#  ('เรา', 'PPRS'),
#  ('ก็', 'JSBR'),
#  ('ได้', 'XVAM'),
#  ('รวบรวม', 'VACT'),
#  (' ', 'PUNC'),
#  ('ของขวัญ', 'NCMN'),
#  ('วาเลนไทน์', 'NCMN'),
#  (' ', 'PUNC'),
#  ('เก๋', 'NCMN'),
#  ('ๆ', 'PUNC'),
#  (' ', 'PUNC'),
#  ('ที่', 'PREL'),
#  ('เหมาะ', 'VSTA'),
#  ('กับ', 'RPRE'),
#  ('การ', 'FIXN'),
#  ('มอบ', 'VACT'),
#  ('ให้', 'JSBR'),
#  ('คน', 'NCMN'),
#  ('รัก', 'NCMN'),
#  ('ใน', 'RPRE'),
#  ('เทศกาล', 'NCMN'),
#  ('แห่ง', 'RPRE'),
#  ('ความ', 'FIXN'),
#  ('รัก', 'VSTA'),
#  ('นี้', 'DDAC'),
#  ('กัน', 'ADVN'),
#  ('ซัก', 'NCMN'),
#  ('หน่อย', 'NCMN'),
#  (' ', 'PUNC'),
#  ('จะ', 'XVBM'),
#  ('มี', 'VSTA'),
#  ('อะไร', 'PNTR'),
#  ('บ้าง', 'ADVN'),
#  (' ', 'PUNC'),
#  ('มา', 'XVAE'),
#  ('ดู', 'VACT'),
#  ('กัน', 'ADVN'),
#  ('เลย', 'XVAE')]

# %%
def Selected_pos(list_of_word,type_pos='NOUN'):
    ''' Selected pos from list of word'''
    result=[]
    for word,pos in list_of_word:
        # เลือกเฉพาะคำที่มี pos เหมือนกับที่กำหนดไว้ใน type_pos
        if type_pos==pos:
            result.append(word)
    return result

# %%
# เลือก Active Verb (VACT) เพื่อต้องการหากิจกรรมที่ทำในข่าวแต่ล่ะประเภท 
# และ Common Noun (NCMN) เพื่อหาสิ่งที่เกี่ยวข้องกับข่าวแต่ละประเภท
# เลือกคำในที่เป็น VACT','NCMN' ในข่าว
df_sel['VACT']=df_sel['pos_tag'].apply(lambda x:Selected_pos(x,'VACT'))
df_sel['NCMN']=df_sel['pos_tag'].apply(lambda x:Selected_pos(x,'NCMN'))

# %%
# สร้าง wordcloud ของ Active Verb และ Common Noun ของข่าวแต่ละประเภท
import nltk
from wordcloud import WordCloud 
import matplotlib.pyplot as plt 
from itertools import chain

#สร้าง list ของประเภทข่าว
sections=['Campus', 'Game', 'Hitech', 'Money', 'Movie', 'Sport', 'Travel']
# path ใข้ save
save_path=r'/content/drive/MyDrive/NLP/Day2/POS_NER_analysis/POS//'

for section in sections:
    print(section,'Active Verb')
    # สร้าง list ของคำที่เป็นคำ Active Verb ของข่าวแต่ละประเภท
    section_list=df_sel[df_sel['new_section']==section]['VACT'].tolist()
    # แปลงจาก 2D list เป็น 1D list ex. [['กิน','อยู่' ,'ไป']]=>['กิน','อยู่' ,'ไป']
    section_ = list(chain.from_iterable(section_list))
    # เลือกเฉพาะคำที่มีจำนวนพยางค์มากกว่า 0
    section_=[w for w in section_ if len(w)>1]
    # หาความถี่ของคำในข่าวแต่ละประเภทโดยใช้คำสั่ง nltk.FreqDist()
    fdist1 = nltk.FreqDist(section_)
    # wordcloud ที่แสดงคำที่มีความถี่สูงสุด
    wordcloud = WordCloud(font_path=r'/content/drive/MyDrive/NLP/Day2/POS_NER_analysis/THSarabunNew001.ttf',
                    background_color ='black', 
                    colormap='Pastel1',
                    min_font_size = 15
                    )
    wordcloud.generate_from_frequencies(fdist1)
    plt.figure(figsize = (6, 8), facecolor = None) 
    plt.imshow(wordcloud, cmap=plt.cm.gray, interpolation='bilinear')
    plt.axis("off") 
    plt.tight_layout(pad = 0)   
    plt.show()
    wordcloud.to_file(save_path+"snook_VACT_"+section+".png") 
    plt.close()
# Out:
# Campus Active Verb
# Game Active Verb
# Hitech Active Verb
# Money Active Verb
# Movie Active Verb
# Sport Active Verb
# Travel Active Verb

# %%
for section in sections:
    print(section,'Common Noun')
    # สร้าง list ของคำที่เป็นคำCommon Noun ของข่าวแต่ละประเภท
    section_list=df_sel[df_sel['new_section']==section]['NCMN'].tolist()
    # แปลงจาก 2D list เป็น 1Dlist ex. [['กิน','อยู่' ,'ไป']]=>['กิน','อยู่' ,'ไป']
    section_ = list(chain.from_iterable(section_list))
    # เลือกเฉพาะคำที่มีจำนวนพยางค์มากกว่า 0
    section_=[w for w in section_ if len(w)>1]
    # หาความถี่ของคำในข่าวแต่ละประเภทโดยใช้คำสั่ง nltk.FreqDist()
    fdist1 = nltk.FreqDist(section_)
    # wordcolud ที่แสดงคำที่มีความถี่สูงสุด
    wordcloud = WordCloud(font_path=r'/content/drive/MyDrive/NLP/Day2/POS_NER_analysis/THSarabunNew001.ttf',
                    background_color ='black', 
                    colormap='Pastel1',
                    min_font_size = 15
                    )
    wordcloud.generate_from_frequencies(fdist1)
    plt.figure(figsize = (6, 8), facecolor = None) 
    plt.imshow(wordcloud, cmap=plt.cm.gray, interpolation='bilinear')
    plt.axis("off") 
    plt.tight_layout(pad = 0)   
    plt.show()
    wordcloud.to_file(save_path+"snook_NCMN_"+section+".png") 
    plt.close()
# Out:
# Campus Common Noun
# Game Common Noun
# Hitech Common Noun
# Money Common Noun
# Movie Common Noun
# Sport Common Noun
# Travel Common Noun

# %% [markdown]
# **Summary :**
#
# 1.   กิจกรรมหรือการกระทำในเนื้อข่าวของแต่ประเภท
#
#   จากtag VACT ของ POS หรือ Active Verb จะเห็นได้ว่ากิจกรรมที่ทำนั้นสอดคล้องกับประเภทของข่าว
#   *   ข่าวเกี่ยวกับการศึกษา( Campus)
#   กิจกรรมที่พบได้เยอะในเนื้อข่าวจะเกี่ยวกับการเรียน การอ่าน การคิด การบรรยาย
#   *   ข่าวเกี่ยวกับเกมส์(Game)กิจกรรมที่พบได้เยอะในเนื้อข่าวจะเกี่ยวกับการเล่น สร้าง พัฒนา
#   *   ข่าวเกี่ยวกับเทคโนโลยี(Hitech)กิจกรรมที่พบได้เยอะในเนื้อข่าวจะเกี่ยวกับการใช้ การเข้า การเลือก การพัฒนาซึ่งจะมีกิจกรรมที่คล้ายกับเนื้อข่าวในเกมส์
#   *   ข่าวเกี่ยวกับเศรษฐกิจ(Money)กิจกรรมที่พบได้เยอะในเนื้อข่าวจะเกี่ยวกับการรับ ทำ ขาย ปรับ ซื้อ
#   *   ข่าวเกี่ยวกับหนัง(Movie)กิจกรรมที่พบได้เยอะในเนื้อข่าวจะเกี่ยวกับการแสดง ดู ติดตาม เล่น
#   *   ข่าวเกี่ยวกับกีฬา(Sport)กิจกรรมที่พบได้เยอะในเนื้อข่าวจะเกี่ยวกับการแข่งขัน เข้า รับ เล่น
#   *   ข่าวเกี่ยวกับท่องเที่ยว(Travel)กิจกรรมที่พบได้เยอะในเนื้อข่าวจะเกี่ยวกับการเดินทาง เที่ยว ท่องเที่ยว
# 2.  สิ่งที่เกี่ยวข้องกับข่าวแต่ละประเภท
#
#     จากtag NCMN ของ POS หรือ Common noun จะเห็นได้ว่าคน สิ่งของซึ่งเป็นคำนามนั้นสอดคล้องกับประเภทของข่าว
#   *   ข่าวเกี่ยวกับการศึกษา( Campus)
#   คำที่พบได้เยอะในเนื้อข่าวสามารถบ่งบอกถึงการศึกษาอย่างชัดเจนได้แค่คำว่าครูู
#   *   ข่าวเกี่ยวกับเกมส์(Game)คำที่พบได้เยอะในเนื้อข่าวนั้นเกี่ยวกับเกม คน ตัว งาน ทีม ระบบ ซึ่งสอดคล้องกับประเภทของข่าว
#   *   ข่าวเกี่ยวกับเทคโนโลยี(Hitech)คำที่พบได้เยอะในเนื้อข่าวนั้นเกี่ยวกับงาน ระบบ เครื่อง ภาพ รวมทั้ง galaxy iphone samsung ซึ่งสอดคล้องกับประเภทของข่าว
#   *   ข่าวเกี่ยวกับเศรษฐกิจ(Money)คำที่พบได้เยอะในเนื้อข่าวนั้นเกี่ยวกับเงิน ราคา ค่า ตลาด ดอลลาร์ ซึ่งสอดคล้องกับประเภทของข่าว
#   *   ข่าวเกี่ยวกับหนัง(Movie)คำที่พบได้เยอะในเนื้อข่าวนั้นเกี่ยวกับงาน เรื่อง คน ซีรีส์ ละคร ซึ่งสอดคล้องกับประเภทของข่าว
#   *   ข่าวเกี่ยวกับกีฬา(Sport)คำที่พบได้เยอะในเนื้อข่าวนั้นเกี่ยวกับบอล ทีม วัน เกม กีฬา ซึ่งสอดคล้องกับประเภทของข่าว
#   *   ข่าวเกี่ยวกับท่องเที่ยว(Travel)คำที่พบได้เยอะในเนื้อข่าวนั้นเกี่ยวกับร้าน วัน ไม้ อาหาร วิวซึ่งสอดคล้องกับประเภทของข่าว

# %% [markdown]
# # Named Entity Recognition(NER)

# %%
from pythainlp.wangchanberta import ThaiNameTagger
# Out:
# Downloading (…)tencepiece.bpe.model:   0%|          | 0.00/905k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/282 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/546 [00:00<?, ?B/s]
# /usr/local/lib/python3.9/dist-packages/pythainlp/wangchanberta/postag.py:26: UserWarning:
#             LST20 corpus are free for research and open source only.
#
#             If you want to use in Commercial use, please contract NECTEC.
#
#             https://www.facebook.com/dancearmy/posts/10157641945708284
#
#   warnings.warn("""
# Downloading (…)st20-pos/config.json:   0%|          | 0.00/1.06k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/419M [00:00<?, ?B/s]
# /usr/local/lib/python3.9/dist-packages/transformers/pipelines/token_classification.py:159: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="none"` instead.
#   warnings.warn(

# %%
# ใช้คำสั่ง ThaiNameTagger() โดยใช้ datasetของ lst20 
NER_model = ThaiNameTagger(dataset_name="lst20")
# Out:
# <ipython-input-28-f576d972377f>:2: DeprecationWarning: dataset_name='lst20' of class `ThaiNameTagger` will be deprecated in version 4.0.0.
#   NER_model = ThaiNameTagger(dataset_name="lst20")
# Downloading (…)st20-ner/config.json:   0%|          | 0.00/1.69k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/419M [00:00<?, ?B/s]
# /usr/local/lib/python3.9/dist-packages/transformers/pipelines/token_classification.py:159: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="simple"` instead.
#   warnings.warn(

# %%
df_sel['Text_real'][900][0]
# Out:
# 'งานนี้จะไม่ให้ลุ้นยังไงไหว ก็เรื่องราวของ นางนาค สะใภ้พระโขนง ละครเวิร์คพอยท์ ช่องเวิร์คพอยท์23 เล่นทวีความเข้มข้นขึ้นทุกขณะ โดยเฉพาะตอนนี้ ที่ ป้าจันทร์ กำลังไล่ล่าหาความจริงจนเกือบจะได้รู้ว่า ใคร  ทำให้ นางนาค มายด์ อาทิตยา ต้องตายทั้งกลมอย่างทนทุกข์ทรมาน'

# %%
# แสดงตำแหน่งของ NER ในเอกสารโดยมี tag ครอบคำนั้น
text=NER_model.get_ner(df_sel['Text_real'][900][0],tag=True)
text
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# 'งานนี้จะไม่ให้ลุ้นยังไงไหว  ก็เรื่องราวของ <PER>นางนาค</PER>  สะใภ้พระโขนง ละคร<ORG>เวิร์ค</ORG>พอยท์ <ORG>ช่องเวิร์คพอยท์23</ORG>  เล่นทวีความเข้มข้นขึ้นทุกขณะ  โดยเฉพาะตอนนี้  ที่ <PER>ป้าจันทร์</PER>  กําลังไล่ล่าหาความจริงจนเกือบจะได้รู้ว่า  ใคร   ทําให้ <PER>นางนาค</PER> <PER>มายด์</PER> <PER>อาทิตยา</PER> ต้องตายทั้งกลมอย่างทนทุกข์ทรมาน'

# %%
def NER_in_text(list_of_text):
    ''' Specify NER in text'''
    ner_tag=[]
    for text in list_of_text:
        try:
            # แสดงตำแหน่งของ NER ในเอกสารโดยมี tag ครอบคำนั้น
            tag_text=NER_model.get_ner(text,tag=True)
        except:
            tag_text='none'
        ner_tag.append(tag_text)
    return ner_tag

# %%
# หา NER ในแต่ละข่าว
df_sel['NER_all']=df_sel['Text_real'].apply(lambda x: NER_in_text(x))

# %%
NER_in_text(df_sel['Text_real'][900])

# %%
from nltk.tokenize import RegexpTokenizer
# ใช้ nltk.tokenize.RegexpTokenizer เพื่อหา NER ในแต่ละ entity
# <PER>ป้าจันทร์</PER> ให้เป็น ('PER','ป้าจันทร์','PER')
pattern = r'\<(.*?)\>(.*?)\<\/(.*?)\>'
tokenizer = RegexpTokenizer(pattern)

# %%
# เนื่องจาก model แสดงค่า <unk> เมื่อไม่สามารถที่จะบ่งบอกชนิดของคำได้
# และมี < > ซึ่งเป็นอุปสรรคในการค้นหา NER ดังนั้นจึงลบออกจากข้อความ
df_sel['NER_all']=df_sel['NER_all'].apply( lambda x :[re.sub('\<unk\>'," ",w) for w in x] )

# %%
def ner_extract_tag(ner_tag_list):
    ''' Extract word and entity from pattern'''
    result=[]
    for ner_tag in ner_tag_list:
        entity_list=tokenizer.tokenize(ner_tag)
        result.append(entity_list)
    return result

# %%
# สกัดคำที่มี entity ออกมาจากข้อความของข่าว
df_sel['NER_extract']=df_sel['NER_all'].apply(lambda x:ner_extract_tag(x) )

# %%
df_sel['NER_extract'][900]

# %%
def Select_entity(ner_extract_list,entity):
    ''' Select words from the choosing entity from extracted NER'''
    words_list=[]
    # ner_extract ในแต่ละย่อหน้า
    for ner_extract in ner_extract_list:
        if len(ner_extract)>0:
            # เลือกคำที่ตรงกับ entity ที่ต้องการ
            for opentag,word,closetag in ner_extract:
                if opentag==entity:
                        words_list.append(word)
    return words_list

# %%
# เลือกคำที่เป็น ORG:Organization  
df_sel['ORG'] =df_sel['NER_extract'].apply(lambda x:Select_entity(x,'ORG') )

# %%
save_path=r'/content/drive/MyDrive/NLP/Day2/POS_NER_analysis/NER//'
sections=['Campus', 'Game', 'Hitech', 'Money', 'Movie', 'Sport', 'Travel']
for section in sections:
    print(section,'Organization')
    # สร้าง list ของคำที่เป็นชื่อหน่วยงาน
    section_list=df_sel[df_sel['new_section']==section]['ORG'].tolist()
    # แปลงจาก 2D list เป็น 1Dlist ex. [['กิน','อยู่' ,'ไป']]=>['กิน','อยู่' ,'ไป']
    section_ = list(chain.from_iterable(section_list))
    section_=[w for w in section_ if len(w)>1]
    # หาความถี่ของคำในข่าวแต่ละประเภทโดยใช้คำสั่ง nltk.FreqDist()
    fdist1 = nltk.FreqDist(section_)
    #  wordcolud ที่แสดงคำที่มีความถี่สูงสุด
    wordcloud = WordCloud(font_path=r'/content/drive/MyDrive/NLP/Day2/POS_NER_analysis/THSarabunNew001.ttf',
                    background_color ='black', 
                    colormap='Pastel1',
                    min_font_size = 15
                    )
    wordcloud.generate_from_frequencies(fdist1)
    plt.figure(figsize = (6, 8), facecolor = None) 
    plt.imshow(wordcloud, cmap=plt.cm.gray, interpolation='bilinear')
    plt.axis("off") 
    plt.tight_layout(pad = 0)   
    plt.show()
    wordcloud.to_file(save_path+"snook_ORG_"+section+".png") 
    plt.close()

# %% [markdown]
# Summary :
#
# 1.   องค์กรหรือหน่วยงานที่เกี่ยวข้องกับเนื้อข่าวของแต่ประเภท
#
#   จากtag ORG ของ NER หรือ Organization จะเห็นได้ว่าองค์กรหรือหน่วยงานนั้นมีความสอดคล้องกับประเภทของข่าว
#   *   ข่าวเกี่ยวกับการศึกษา( Campus)
#   องค์กรหรือหน่วยงานที่พบได้เยอะในเนื้อข่าวจะเกี่ยวกับมหาวิทยาลัยมหิดล มธ คณะวิทยาการเรียนรู้และศึกษาศาสตร์
#   *   ข่าวเกี่ยวกับเกมส์(Game)องค์กรหรือหน่วยงานที่พบได้เยอะในเนื้อข่าวจะเกี่ยวกับsony huawei microsoft ea
#   *   ข่าวเกี่ยวกับเทคโนโลยี(Hitech)องค์กรหรือหน่วยงานที่พบได้เยอะในเนื้อข่าวจะเกี่ยวกับsamsung oppa google apple netflix
#   *   ข่าวเกี่ยวกับเศรษฐกิจ(Money)องค์กรหรือหน่วยงานที่พบได้เยอะในเนื้อข่าวจะเกี่ยวกับสหรัฐฯ ธกส กระทรวงการลัง เฟด
#   *   ข่าวเกี่ยวกับหนัง(Movie)องค์กรหรือหน่วยงานที่พบได้เยอะในเนื้อข่าวจะเกี่ยวกับgmmtv netflix wetv ช่อง 3
#   *   ข่าวเกี่ยวกับกีฬา(Sport)องค์กรหรือหน่วยงานที่พบได้เยอะในเนื้อข่าวจะเกี่ยวกับลิเวอร์พูล เชลซี เรอัล มาดริด
#   *   ข่าวเกี่ยวกับท่องเที่ยว(Travel)องค์กรหรือหน่วยงานที่พบได้เยอะในเนื้อข่าวจะสอดคล้องเกี่ยวกับข่าวการศึกษาซึ่งมีเนื้อหาข่าวเกี่ยวกับคณะสถาปัตยกรรมศาสตร์ มหาวิทยาลัยศิลปากร ญี่ปุ่น

# %%
# df_sel.to_pickle('/content/drive/MyDrive/NLP_tutorial/POS_NER/Snook_ner.pkl')

# %% [markdown]
# Reference
#
#
# *   https://colab.research.google.com/drive/1XV2aR_KYrO16iKHKtO0MtufWOFeiFKsc?usp=drive_open
# *   List item
